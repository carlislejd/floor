# %%
import pymongo
import requests
import pandas as pd

from os import getenv
from datetime import datetime
from dotenv import load_dotenv

from config import contract_collection
from helper import contract_list


load_dotenv()

import warnings
warnings.filterwarnings('ignore')

pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', None)

# %%
def get_collection_activity(metadata, limit, collection=None, collectionssetid=None, community=None, continuation=None):
    url = 'https://api.reservoir.tools/'
    end_point = 'collections/activity/v5'
    headers = {'accept': '*/*', 'x-api-key': f"{getenv('RESERVOIR')}"}
    if community == None:
        r = requests.get(url + end_point, params=f'?sortBy=eventTimestamp&includeMetadata={metadata}&limit={limit}', headers=headers)
    else:
        r = requests.get(url + end_point, params=f'?sortBy=eventTimestamp&includeMetadata={metadata}&limit={limit}&community={community}', headers=headers)
    data = r.json()
    return data

# %%
contract_db = contract_list()

test = get_collection_activity(True, 20, community='artblocks')
new_bids = []
for item in test['activities']:
    if item['type'] == 'bid':
        if item['order']['criteria']['kind'] == 'collection':
            actions = {}
            actions['contract'] = item['contract']
            actions['collection_name'] = item['collection']['collectionName']
            actions['collection_id'] = item['order']['criteria']['data']['collection']['id']
            if item['order']['criteria']['data']['collection']['id'] not in contract_db:
                new_bids.append(actions)

if new_bids:               
    contract_collection().insert_many(new_bids)

contract_db = contract_list()
df = pd.DataFrame(contract_db)

# %%
def get_collection_info(limit, topbid, normalize, c_id=None):
    url = 'https://api.reservoir.tools/'
    end_point = 'collections/v5'
    headers = {'accept': '*/*', 'x-api-key': f"{getenv('RESERVOIR')}"}
    r = requests.get(url + end_point, params=f'id={c_id}&includeTopBid={topbid}&normalizeRoyalties={normalize}&sortBy=allTimeVolume&limit={limit}', headers=headers)
    data = r.json()
    return data

# %%
new_bids = []
for c in contract_db:
    collections = get_collection_info(1, True, False, c_id=c)
    for collection in collections['collections']:
        project = {}
        id = collection['id']
        project['Collection'] = collection['name']
        contract = collection['primaryContract']
        token_range = collection['tokenSetId'].split(':')[2:]
        project['7day Volume'] = round(collection['volume']['7day'], 2)
        project['Lowest Floor Price'] = f"{str(collection['floorAsk']['sourceDomain'])} : {round(collection['floorAsk']['price']['amount']['decimal'], 3)}"
        try:
            project['Highest Collection Offer'] = f"{str(collection['topBid']['sourceDomain'])} : {round(collection['topBid']['price']['amount']['decimal'], 3)}"
            project['Spread'] = round(float((collection['floorAsk']['price']['amount']['decimal']) - float(collection['topBid']['price']['amount']['decimal'])) / float(collection['floorAsk']['price']['amount']['decimal']), 2)
        except TypeError:
            project['Highest Collection Offer'] = 'None'
            project['Spread'] = 'None'
        new_bids.append(project)
    

df = pd.DataFrame(new_bids)

# %%
df[~df['Spread'].isin(['None'])].sort_values(by='Collection', ascending=True).to_csv('spread.csv', index=False)

# %%
get_activity(False, 20, 'desc')
# Out:
# {'activities': [{'id': 1254750014,
#    'type': 'bid',
#    'contract': '0x092bbc993042a69811d23feb0e64e3bfa0920c6a',
#    'collectionId': '0x092bbc993042a69811d23feb0e64e3bfa0920c6a',
#    'tokenId': '28685',
#    'fromAddress': '0x48063703c49c498878f4be77c29ac1f6e510e1ab',
#    'toAddress': None,
#    'price': 0.15705,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x26cafa331ec11b650d64219d9b3253fe708182efd250fce6a0682ae5baa4593e'}},
#   {'id': 1254750013,
#    'type': 'bid',
#    'contract': '0x345c2fa23160c63218dfaa25d37269f26c85ca47',
#    'collectionId': '0x345c2fa23160c63218dfaa25d37269f26c85ca47',
#    'tokenId': '3749',
#    'fromAddress': '0xc07003bbd24c2efa3a93d79cac54fac71b1a1a1a',
#    'toAddress': None,
#    'price': 0.15047,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x3187db7bd3d952c10fa2b82b7b7cfa3ad7b793cf52cb01eb75d8cedc424e496d'}},
#   {'id': 1254750012,
#    'type': 'bid',
#    'contract': '0x740c178e10662bbb050bde257bfa318defe3cabc',
#    'collectionId': '0x740c178e10662bbb050bde257bfa318defe3cabc',
#    'tokenId': None,
#    'fromAddress': '0x047e6bfad85247b012521892f5bb684f50f2e466',
#    'toAddress': None,
#    'price': 0.48881,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0xf69a3aa58dcab1a0696e51a5356bc32bf7a0ebfd8e98f7bbe283fc7cd257ba1a'}},
#   {'id': 1254750011,
#    'type': 'bid',
#    'contract': '0x4d3709b78b5868ce9abbf2cae667fcd23258bcb8',
#    'collectionId': '0x4d3709b78b5868ce9abbf2cae667fcd23258bcb8',
#    'tokenId': '3693',
#    'fromAddress': '0xb6f38280e36f6efacdb535e539a95c391b26047b',
#    'toAddress': None,
#    'price': 0.0918,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x6bebeb7f32d867ed79f7a5ef4fd5c9623da4445b40adf5514f1a77369c6c3ec4'}},
#   {'id': 1254750010,
#    'type': 'bid',
#    'contract': '0x96be46c50e882dbd373081d08e0cde2b055adf6c',
#    'collectionId': '0x96be46c50e882dbd373081d08e0cde2b055adf6c',
#    'tokenId': '25505',
#    'fromAddress': '0x45b5ad9e8001ef7951537a28fea5d9dbe13b380a',
#    'toAddress': None,
#    'price': 0.07722,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x59ca27cc9ad40d4f9eb6d229db23553bbf4b7879e4787392b72bf435ca644c0d'}},
#   {'id': 1254750009,
#    'type': 'bid',
#    'contract': '0x9231f13343f871b051fa5002e8c04beed91b4f62',
#    'collectionId': '0x9231f13343f871b051fa5002e8c04beed91b4f62',
#    'tokenId': '2509',
#    'fromAddress': '0xc35de3eb8d2cb560bf90c4a0caa737d2a701f695',
#    'toAddress': None,
#    'price': 0.0807,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x2cbd293bf9c53a28a8e45ce4d0fe02db09321afc37d614680b01cc5e93ec8270'}},
#   {'id': 1254750008,
#    'type': 'bid',
#    'contract': '0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85',
#    'collectionId': '0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85',
#    'tokenId': '63121874640934203216615260348024525396436979230954810277949840507017391205321',
#    'fromAddress': '0x18ac92fc101f4664bd7200b044b57918c63f50ef',
#    'toAddress': None,
#    'price': 1.1578,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0xbf1b127685eb7bd6a66e0ba8b6289dbce021405f83c7636e17bee54651c4695f'}},
#   {'id': 1254750007,
#    'type': 'bid',
#    'contract': '0x5c1a0cc6dadf4d0fb31425461df35ba80fcbc110',
#    'collectionId': '0x5c1a0cc6dadf4d0fb31425461df35ba80fcbc110',
#    'tokenId': '2892',
#    'fromAddress': '0xcf8b597742d314fb196700a9953338e8fbe46345',
#    'toAddress': None,
#    'price': 0.47341,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x92698324a6c006927b32d1f9486a62e1fc9826b3a49016d00c1027e97e0e1fb5'}},
#   {'id': 1254750006,
#    'type': 'bid',
#    'contract': '0x080e92b26a1d93546d2f5a8ef05a8b823306c146',
#    'collectionId': '0x080e92b26a1d93546d2f5a8ef05a8b823306c146',
#    'tokenId': '30000963',
#    'fromAddress': '0xe98aabc672898d743574cac0102a02834ad5a06c',
#    'toAddress': None,
#    'price': 0.1812,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0xbfb5b822cfbfae77f6b0f806ed68b2a4fb37a9b55cbf696637b88bab44e8a6f8'}},
#   {'id': 1254750005,
#    'type': 'bid',
#    'contract': '0x4a537f61ef574153664c0dbc8c8f4b900cacbe5d',
#    'collectionId': '0x4a537f61ef574153664c0dbc8c8f4b900cacbe5d',
#    'tokenId': '6636',
#    'fromAddress': '0x668b78ce9308c5859ed3c2958b0d71de9c2cc2a4',
#    'toAddress': None,
#    'price': 0.5565,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x9f751767b9c5fcbcf7721f6b116e61c6ed60339a137fb66be087583efdb47658'}},
#   {'id': 1254750004,
#    'type': 'bid',
#    'contract': '0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258',
#    'collectionId': '0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258',
#    'tokenId': '1420',
#    'fromAddress': '0xf9fe45cced031ce806199b0a032df42f15e095b6',
#    'toAddress': None,
#    'price': 13.5022,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0xf4e4a8d4d213b956626b7e28f9950288b2b8731493b367ca93e41c878d08c01e'}},
#   {'id': 1254750003,
#    'type': 'bid',
#    'contract': '0xb4d06d46a8285f4ec79fd294f78a881799d8ced9',
#    'collectionId': '0xb4d06d46a8285f4ec79fd294f78a881799d8ced9',
#    'tokenId': None,
#    'fromAddress': '0x059930dfcca5332613126bc0008278c9b5172825',
#    'toAddress': None,
#    'price': 0.1792,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x35c28549ce1f7e6dd18e0588a7ef4fa60df3bc8c329af6a2e0d8769a2931da34'}},
#   {'id': 1254749999,
#    'type': 'bid',
#    'contract': '0x249aeaa7fa06a63ea5389b72217476db881294df',
#    'collectionId': '0x249aeaa7fa06a63ea5389b72217476db881294df',
#    'tokenId': None,
#    'fromAddress': '0x06bbbb68c1ebd9eb7e0a58911609b7728b3ea575',
#    'toAddress': None,
#    'price': 0.30641,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x8228b90bd5268afe4de267559a0a952f86c223fb340989321350ed60767bf554'}},
#   {'id': 1254749998,
#    'type': 'bid',
#    'contract': '0x885525b82e8ab86c5f463cef0a4b19a43ef005c5',
#    'collectionId': '0x885525b82e8ab86c5f463cef0a4b19a43ef005c5',
#    'tokenId': None,
#    'fromAddress': '0xe6fc5c50c8f6df408ba4d1b56bcd9756c69e2304',
#    'toAddress': None,
#    'price': 0.0436,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0xd4703bfec5aa90e8671dd97bfa4eeebce0795d7bce1797ba757ad2a0c74da757'}},
#   {'id': 1254749985,
#    'type': 'bid',
#    'contract': '0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb',
#    'collectionId': '0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb',
#    'tokenId': None,
#    'fromAddress': '0xb095d9f608d77b95f3ce175ba3cd63534750d60c',
#    'toAddress': None,
#    'price': 3.74092,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x6ed4231ea5e25f41d3eccb4306cfa7c5fa22303a9e4b097bc0acac9facdfa8e1'}},
#   {'id': 1254749926,
#    'type': 'bid',
#    'contract': '0x942bc2d3e7a589fe5bd4a5c6ef9727dfd82f5c8a',
#    'collectionId': '0x942bc2d3e7a589fe5bd4a5c6ef9727dfd82f5c8a',
#    'tokenId': '17150',
#    'fromAddress': '0x294346fa69f2286cb0460917d457bb4bdca19951',
#    'toAddress': None,
#    'price': 0.35,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0xc38fbc96fbf0dc61817e5bed53219f8100d20a90dec8b43b1319de9d6e46b9f5'}},
#   {'id': 1254749802,
#    'type': 'bid',
#    'contract': '0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85',
#    'collectionId': '0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85',
#    'tokenId': '102667734394434433956401369339557131726134561204738743510049034286435000467920',
#    'fromAddress': '0xf9c40896e98543bdceee03779262c7af18c84f77',
#    'toAddress': None,
#    'price': 1.1655,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0xf8c62c27b0bf383994c52809a5ec0cc4ec35cad63202d2b3dce4587ccea89690'}},
#   {'id': 1254749796,
#    'type': 'bid',
#    'contract': '0x231d3559aa848bf10366fb9868590f01d34bf240',
#    'collectionId': '0x231d3559aa848bf10366fb9868590f01d34bf240',
#    'tokenId': '6018',
#    'fromAddress': '0x6bc0931d751711b652e0618b296da9764af73518',
#    'toAddress': None,
#    'price': 0.46,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x7df723a265b82047f4b3e891fce128cfab99533ac75704a554e537931f92bf8d'}},
#   {'id': 1254749792,
#    'type': 'bid',
#    'contract': '0x942bc2d3e7a589fe5bd4a5c6ef9727dfd82f5c8a',
#    'collectionId': '0x942bc2d3e7a589fe5bd4a5c6ef9727dfd82f5c8a',
#    'tokenId': '14836',
#    'fromAddress': '0xabbcc02888e17e7940d5efa21d3e6ef14af7ee21',
#    'toAddress': None,
#    'price': 0.35045,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x54c61aedda7aeba49e0c802feb71decc22150608f902c67ccc4da7572977619a'}},
#   {'id': 1254749786,
#    'type': 'ask',
#    'contract': '0x8bdfd304d22c9f02d542b59aa9b91236c21dfd82',
#    'collectionId': '0x8bdfd304d22c9f02d542b59aa9b91236c21dfd82',
#    'tokenId': '2747',
#    'fromAddress': '0xaef24a992f2bd812d201cd5b7ffa4948af6f5bf0',
#    'toAddress': None,
#    'price': 0.13,
#    'amount': 1,
#    'timestamp': 1670448649,
#    'order': {'id': '0x0d1090765207f1721aaec3a9287fcf5d0719f19214ce28d97c7095d70c489087'}}],
#  'continuation': 'MTY3MDQ0ODY0OV8xMjU0NzQ5Nzg2'}

# %%
url = 'https://api.reservoir.tools/'

response = requests.get(url, json={'limit': 20, 'includeMetadata': False}, headers=headers)

print(response.url)
test = response.json()
# Out:
# https://api.reservoir.tools/activity/v4
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\PC\Documents\Github\floor\research.ipynb Cell 2 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/floor/research.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> response = requests.get(url + end_point, json={'limit': 20, 'includeMetadata': False}, headers=headers)
#       <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/floor/research.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> print(response.url)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/floor/research.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> test = response.json()
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
url = "https://api.reservoir.tools/orders/bids/v5?community=artblocks&includeCriteriaMetadata=false&includeRawData=false&normalizeRoyalties=false&sortBy=createdAt&limit=50"
headers = {
    "accept": "*/*",
    "x-api-key": "demo-api-key"
}

# %%
def mongo_collection():
    client = pymongo.MongoClient(getenv('MONGO'))
    db = client.nonfungible 
    return db.globalcontracts

# %%
db = mongo_collection()

db.find_one()
# Out:
# {'_id': ObjectId('61bb564679a8467985b2be61'),
#  'address': 'simpleassets',
#  'isERC20': False,
#  'isERC721': True,
#  'doSaveTX': True,
#  'blockchain': 'wax'}

# %%
start_block = init_collection.find({'blockchain': 'flow'}).sort('blockNumber', -1).limit(1).next()['blockNumber'] - 25
